# %%
#pip install earthengine-api google-auth
#pip install earthengine-api geopandas pandas
#pip install earthengine-api google-auth google-auth-oauthlib
# Out:
# Requirement already satisfied: earthengine-api in c:\users\630595\appdata\local\anaconda3\lib\site-packages (0.1.412)
# Requirement already satisfied: google-auth in c:\users\630595\appdata\local\anaconda3\lib\site-packages (2.32.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\630595\appdata\local\anaconda3\lib\site-packages (from earthengine-api) (2.137.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\630595\appdata\local\anaconda3\lib\site-packages (from earthengine-api) (0.22.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\630595\appdata\local\anaconda3\lib\site-packages (from earthengine-api) (0.2.0)
# Requirement already satisfied: requests in c:\users\630595\appdata\local\anaconda3\lib\site-packages (from earthengine-api) (2.28.1)
# Requirement already satisfied: google-cloud-storage in c:\users\630595\appdata\local\anaconda3\lib\site-packages (from earthengine-api) (2.17.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\630595\appdata\local\anaconda3\lib\site-packages (from google-auth) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\630595\appdata\local\anaconda3\lib\site-packages (from google-auth) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\630595\appdata\local\anaconda3\lib\site-packages (from google-auth) (0.2.8)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\630595\appdata\local\anaconda3\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api) (4.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\630595\appdata\local\anaconda3\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api) (2.19.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\630595\appdata\local\anaconda3\lib\site-packages (from httplib2<1dev,>=0.9.2->earthengine-api) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\630595\appdata\local\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth) (0.4.8)
# Requirement already satisfied: google-resumable-media>=2.6.0 in c:\users\630595\appdata\local\anaconda3\lib\site-packages (from google-cloud-storage->earthengine-api) (2.7.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\630595\appdata\local\anaconda3\lib\site-packages (from google-cloud-storage->earthengine-api) (1.5.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\630595\appdata\local\anaconda3\lib\site-packages (from google-cloud-storage->earthengine-api) (2.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\630595\appdata\local\anaconda3\lib\site-packages (from requests->earthengine-api) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\630595\appdata\local\anaconda3\lib\site-packages (from requests->earthengine-api) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\630595\appdata\local\anaconda3\lib\site-packages (from requests->earthengine-api) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\630595\appdata\local\anaconda3\lib\site-packages (from requests->earthengine-api) (1.26.14)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\630595\appdata\local\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.24.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in c:\users\630595\appdata\local\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (5.27.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\630595\appdata\local\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.63.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Environment Setup
# This section handles the installation of required packages and imports essential modules. These modules include those for accessing Google Earth Engine, managing credentials, manipulating data, and handling dates.
#
#
# - **`import ee`**: Imports Google Earth Engine, which allows access to satellite and geospatial data.
# - **`import os`**: The `os` module is used for interacting with the operating system, such as reading environment variables. This helps manage file paths and sensitive information like credentials.
# - **`import json`**: The `json` library is used to handle JSON files. In this script, it’s used to read and parse the credentials needed for Google Earth Engine authentication.
# - **`from google.oauth2 import service_account`**: This import allows for creating credentials that can be used to authenticate to Google services, including Google Earth Engine.
# - **`import google.auth.transport.requests`**: This library is required to facilitate HTTP requests needed during the authentication process.

# %%
import ee
import os
import json
from google.oauth2 import service_account
import google.auth.transport.requests
import pandas as pd
from datetime import datetime, timedelta

# %% [markdown]
# ### Load Credentials and Setup Authentication
# This section loads the service account key from a JSON file, creates the credentials, and refreshes them to get a valid access token. It then initializes the Google Earth Engine API with these credentials. If the authentication is successful, a confirmation message is printed.

# %%
# Path to your service account key file
key_path = r'C:\FWI Python\Weather_data\fwiweather-0f2d02e48d16.json'

# Load the service account key
with open(key_path, 'r') as f:
    credentials_dict = json.load(f)
    
# Create credentials using the service account key
credentials = service_account.Credentials.from_service_account_info(
    credentials_dict,
    scopes=["https://www.googleapis.com/auth/cloud-platform"]
)

# Refresh the credentials to get a valid access token
auth_req = google.auth.transport.requests.Request()
credentials.refresh(auth_req)

# Initialize the Earth Engine module with the credentials
try:
    ee.Initialize(credentials)
    print('Successfully authenticated with Google Earth Engine!')
except ee.EEException as e:
    print(f'Failed to authenticate: {e}')
except Exception as e:
    print(f'An error occurred: {e}')

# %% [markdown]
# ### Function: Get Hourly Weather Data
# This function retrieves hourly weather data from Google Earth Engine for a specified point (latitude and longitude) and date range. It returns the weather data as a list of records.

# %%
def get_hourly_weather_data(lat, lon, start_date, end_date):
    # Define the location
    point = ee.Geometry.Point(lon, lat)
    
    # Define the satellite data collection
    collection = ee.ImageCollection('ECMWF/ERA5_LAND/HOURLY')\
                    .filterDate(start_date, end_date)\
                    .filterBounds(point)
    
    # Get the data over the specified period
    data = collection.getRegion(point, 1000).getInfo()
    
    return data

# %% [markdown]
# ### Function: Process Batch Data
# This function processes the raw batch data retrieved from Google Earth Engine. It converts the data into a pandas DataFrame and formats the timestamp to a datetime object for easier manipulation.

# %%
def process_batch(batch_data):
    columns = batch_data[0]
    rows = batch_data[1:]
    df_batch = pd.DataFrame(rows, columns=columns)
    df_batch['time'] = pd.to_datetime(df_batch['time'], unit='ms')
    return df_batch

# %% [markdown]
# ### Function: Fetch and Save Data
# This function fetches weather data for a given pond in weekly batches and saves it to a CSV file. It processes the data iteratively, writing headers first and appending new data batches until the entire date range is covered.

# %%
def fetch_and_save_data(lat, lon, start_date, end_date, pond_id, output_file, batch_size='1W'):
    start = datetime.strptime(start_date, '%Y-%m-%d')
    end = datetime.strptime(end_date, '%Y-%m-%d')
    
    # Write header to CSV
    header = ['time', 'dewpoint_temperature_2m', 'temperature_2m', 'skin_temperature', 
              'soil_temperature_level_1', 'soil_temperature_level_2', 'soil_temperature_level_3', 
              'soil_temperature_level_4', 'latitude', 'longitude', 'Pond ID']
    with open(output_file, 'w') as f:
        f.write(','.join(header) + '\n')
    
    while start < end:
        batch_end = min(start + timedelta(days=7), end)  # 1 week batch or less if near the end
        
        print(f'Fetching data for {pond_id} from {start.strftime("%Y-%m-%d")} to {batch_end.strftime("%Y-%m-%d")}')
        
        batch_data = get_hourly_weather_data(lat, lon, start.strftime('%Y-%m-%d'), batch_end.strftime('%Y-%m-%d'))
        df_batch = process_batch(batch_data)
        
        df_batch['latitude'] = lat
        df_batch['longitude'] = lon
        df_batch['Pond ID'] = pond_id
        
        # Append to CSV
        df_batch.to_csv(output_file, mode='a', header=False, index=False)
        
        start = batch_end

# %% [markdown]
# ### Pond Data Collection and Processing
# This section defines the location information for each pond, including coordinates and date ranges. It then iterates over each pond and calls the `fetch_and_save_data` function to process and save weather data for each pond into individual CSV files.

# %%
# Define the locations and corresponding Pond IDs with their respective date ranges
ponds_info = {
    'WG-AJU1': {'lat': 16.6330, 'lon': 81.1494, 'start_date': '2022-02-24', 'end_date': '2024-05-15'},
    'WG-CRP1': {'lat': 16.6306, 'lon': 81.1502, 'start_date': '2021-11-18', 'end_date': '2024-05-05'},
    'WG-VMS1': {'lat': 16.6173, 'lon': 81.1349, 'start_date': '2022-06-08', 'end_date': '2024-05-15'}
}

# Process each pond separately
for pond_id, info in ponds_info.items():
    output_file = f'hourly_weather_data_{pond_id}.csv'
    fetch_and_save_data(info['lat'], info['lon'], info['start_date'], info['end_date'], pond_id, output_file)

print("All data has been processed and saved.")
# Out:
# Successfully authenticated with Google Earth Engine!
# Fetching data for WG-AJU1 from 2022-02-24 to 2022-03-03
# Fetching data for WG-AJU1 from 2022-03-03 to 2022-03-10
# Fetching data for WG-AJU1 from 2022-03-10 to 2022-03-17
# Fetching data for WG-AJU1 from 2022-03-17 to 2022-03-24
# Fetching data for WG-AJU1 from 2022-03-24 to 2022-03-31
# Fetching data for WG-AJU1 from 2022-03-31 to 2022-04-07
# Fetching data for WG-AJU1 from 2022-04-07 to 2022-04-14
# Fetching data for WG-AJU1 from 2022-04-14 to 2022-04-21
# Fetching data for WG-AJU1 from 2022-04-21 to 2022-04-28
# Fetching data for WG-AJU1 from 2022-04-28 to 2022-05-05
# Fetching data for WG-AJU1 from 2022-05-05 to 2022-05-12
# Fetching data for WG-AJU1 from 2022-05-12 to 2022-05-19
# Fetching data for WG-AJU1 from 2022-05-19 to 2022-05-26
# Fetching data for WG-AJU1 from 2022-05-26 to 2022-06-02
# Fetching data for WG-AJU1 from 2022-06-02 to 2022-06-09
# Fetching data for WG-AJU1 from 2022-06-09 to 2022-06-16
# Fetching data for WG-AJU1 from 2022-06-16 to 2022-06-23
# Fetching data for WG-AJU1 from 2022-06-23 to 2022-06-30
# Fetching data for WG-AJU1 from 2022-06-30 to 2022-07-07
# Fetching data for WG-AJU1 from 2022-07-07 to 2022-07-14
# Fetching data for WG-AJU1 from 2022-07-14 to 2022-07-21
# Fetching data for WG-AJU1 from 2022-07-21 to 2022-07-28
# Fetching data for WG-AJU1 from 2022-07-28 to 2022-08-04
# Fetching data for WG-AJU1 from 2022-08-04 to 2022-08-11
# Fetching data for WG-AJU1 from 2022-08-11 to 2022-08-18
# Fetching data for WG-AJU1 from 2022-08-18 to 2022-08-25
# Fetching data for WG-AJU1 from 2022-08-25 to 2022-09-01
# Fetching data for WG-AJU1 from 2022-09-01 to 2022-09-08
# Fetching data for WG-AJU1 from 2022-09-08 to 2022-09-15
# Fetching data for WG-AJU1 from 2022-09-15 to 2022-09-22
# Fetching data for WG-AJU1 from 2022-09-22 to 2022-09-29
# Fetching data for WG-AJU1 from 2022-09-29 to 2022-10-06
# Fetching data for WG-AJU1 from 2022-10-06 to 2022-10-13
# Fetching data for WG-AJU1 from 2022-10-13 to 2022-10-20
# Fetching data for WG-AJU1 from 2022-10-20 to 2022-10-27
# Fetching data for WG-AJU1 from 2022-10-27 to 2022-11-03
# Fetching data for WG-AJU1 from 2022-11-03 to 2022-11-10
# Fetching data for WG-AJU1 from 2022-11-10 to 2022-11-17
# Fetching data for WG-AJU1 from 2022-11-17 to 2022-11-24
# Fetching data for WG-AJU1 from 2022-11-24 to 2022-12-01
# Fetching data for WG-AJU1 from 2022-12-01 to 2022-12-08
# Fetching data for WG-AJU1 from 2022-12-08 to 2022-12-15
# Fetching data for WG-AJU1 from 2022-12-15 to 2022-12-22
# Fetching data for WG-AJU1 from 2022-12-22 to 2022-12-29
# Fetching data for WG-AJU1 from 2022-12-29 to 2023-01-05
# Fetching data for WG-AJU1 from 2023-01-05 to 2023-01-12
# Fetching data for WG-AJU1 from 2023-01-12 to 2023-01-19
# Fetching data for WG-AJU1 from 2023-01-19 to 2023-01-26
# Fetching data for WG-AJU1 from 2023-01-26 to 2023-02-02
# Fetching data for WG-AJU1 from 2023-02-02 to 2023-02-09
# Fetching data for WG-AJU1 from 2023-02-09 to 2023-02-16
# Fetching data for WG-AJU1 from 2023-02-16 to 2023-02-23
# Fetching data for WG-AJU1 from 2023-02-23 to 2023-03-02
# Fetching data for WG-AJU1 from 2023-03-02 to 2023-03-09
# Fetching data for WG-AJU1 from 2023-03-09 to 2023-03-16
# Fetching data for WG-AJU1 from 2023-03-16 to 2023-03-23
# Fetching data for WG-AJU1 from 2023-03-23 to 2023-03-30
# Fetching data for WG-AJU1 from 2023-03-30 to 2023-04-06
# Fetching data for WG-AJU1 from 2023-04-06 to 2023-04-13
# Fetching data for WG-AJU1 from 2023-04-13 to 2023-04-20
# Fetching data for WG-AJU1 from 2023-04-20 to 2023-04-27
# Fetching data for WG-AJU1 from 2023-04-27 to 2023-05-04
# Fetching data for WG-AJU1 from 2023-05-04 to 2023-05-11
# Fetching data for WG-AJU1 from 2023-05-11 to 2023-05-18
# Fetching data for WG-AJU1 from 2023-05-18 to 2023-05-25
# Fetching data for WG-AJU1 from 2023-05-25 to 2023-06-01
# Fetching data for WG-AJU1 from 2023-06-01 to 2023-06-08
# Fetching data for WG-AJU1 from 2023-06-08 to 2023-06-15
# Fetching data for WG-AJU1 from 2023-06-15 to 2023-06-22
# Fetching data for WG-AJU1 from 2023-06-22 to 2023-06-29
# Fetching data for WG-AJU1 from 2023-06-29 to 2023-07-06
# Fetching data for WG-AJU1 from 2023-07-06 to 2023-07-13
# Fetching data for WG-AJU1 from 2023-07-13 to 2023-07-20
# Fetching data for WG-AJU1 from 2023-07-20 to 2023-07-27
# Fetching data for WG-AJU1 from 2023-07-27 to 2023-08-03
# Fetching data for WG-AJU1 from 2023-08-03 to 2023-08-10
# Fetching data for WG-AJU1 from 2023-08-10 to 2023-08-17
# Fetching data for WG-AJU1 from 2023-08-17 to 2023-08-24
# Fetching data for WG-AJU1 from 2023-08-24 to 2023-08-31
# Fetching data for WG-AJU1 from 2023-08-31 to 2023-09-07
# Fetching data for WG-AJU1 from 2023-09-07 to 2023-09-14
# Fetching data for WG-AJU1 from 2023-09-14 to 2023-09-21
# Fetching data for WG-AJU1 from 2023-09-21 to 2023-09-28
# Fetching data for WG-AJU1 from 2023-09-28 to 2023-10-05
# Fetching data for WG-AJU1 from 2023-10-05 to 2023-10-12
# Fetching data for WG-AJU1 from 2023-10-12 to 2023-10-19
# Fetching data for WG-AJU1 from 2023-10-19 to 2023-10-26
# Fetching data for WG-AJU1 from 2023-10-26 to 2023-11-02
# Fetching data for WG-AJU1 from 2023-11-02 to 2023-11-09
# Fetching data for WG-AJU1 from 2023-11-09 to 2023-11-16
# Fetching data for WG-AJU1 from 2023-11-16 to 2023-11-23
# Fetching data for WG-AJU1 from 2023-11-23 to 2023-11-30
# Fetching data for WG-AJU1 from 2023-11-30 to 2023-12-07
# Fetching data for WG-AJU1 from 2023-12-07 to 2023-12-14
# Fetching data for WG-AJU1 from 2023-12-14 to 2023-12-21
# Fetching data for WG-AJU1 from 2023-12-21 to 2023-12-28
# Fetching data for WG-AJU1 from 2023-12-28 to 2024-01-04
# Fetching data for WG-AJU1 from 2024-01-04 to 2024-01-11
# Fetching data for WG-AJU1 from 2024-01-11 to 2024-01-18
# Fetching data for WG-AJU1 from 2024-01-18 to 2024-01-25
# Fetching data for WG-AJU1 from 2024-01-25 to 2024-02-01
# Fetching data for WG-AJU1 from 2024-02-01 to 2024-02-08
# Fetching data for WG-AJU1 from 2024-02-08 to 2024-02-15
# Fetching data for WG-AJU1 from 2024-02-15 to 2024-02-22
# Fetching data for WG-AJU1 from 2024-02-22 to 2024-02-29
# Fetching data for WG-AJU1 from 2024-02-29 to 2024-03-07
# Fetching data for WG-AJU1 from 2024-03-07 to 2024-03-14
# Fetching data for WG-AJU1 from 2024-03-14 to 2024-03-21
# Fetching data for WG-AJU1 from 2024-03-21 to 2024-03-28
# Fetching data for WG-AJU1 from 2024-03-28 to 2024-04-04
# Fetching data for WG-AJU1 from 2024-04-04 to 2024-04-11
# Fetching data for WG-AJU1 from 2024-04-11 to 2024-04-18
# Fetching data for WG-AJU1 from 2024-04-18 to 2024-04-25
# Fetching data for WG-AJU1 from 2024-04-25 to 2024-05-02
# Fetching data for WG-AJU1 from 2024-05-02 to 2024-05-09
# Fetching data for WG-AJU1 from 2024-05-09 to 2024-05-15
# Fetching data for WG-CRP1 from 2021-11-18 to 2021-11-25
# Fetching data for WG-CRP1 from 2021-11-25 to 2021-12-02
# Fetching data for WG-CRP1 from 2021-12-02 to 2021-12-09
# Fetching data for WG-CRP1 from 2021-12-09 to 2021-12-16
# Fetching data for WG-CRP1 from 2021-12-16 to 2021-12-23
# Fetching data for WG-CRP1 from 2021-12-23 to 2021-12-30
# Fetching data for WG-CRP1 from 2021-12-30 to 2022-01-06
# Fetching data for WG-CRP1 from 2022-01-06 to 2022-01-13
# Fetching data for WG-CRP1 from 2022-01-13 to 2022-01-20
# Fetching data for WG-CRP1 from 2022-01-20 to 2022-01-27
# Fetching data for WG-CRP1 from 2022-01-27 to 2022-02-03
# Fetching data for WG-CRP1 from 2022-02-03 to 2022-02-10
# Fetching data for WG-CRP1 from 2022-02-10 to 2022-02-17
# Fetching data for WG-CRP1 from 2022-02-17 to 2022-02-24
# Fetching data for WG-CRP1 from 2022-02-24 to 2022-03-03
# Fetching data for WG-CRP1 from 2022-03-03 to 2022-03-10
# Fetching data for WG-CRP1 from 2022-03-10 to 2022-03-17
# Fetching data for WG-CRP1 from 2022-03-17 to 2022-03-24
# Fetching data for WG-CRP1 from 2022-03-24 to 2022-03-31
# Fetching data for WG-CRP1 from 2022-03-31 to 2022-04-07
# Fetching data for WG-CRP1 from 2022-04-07 to 2022-04-14
# Fetching data for WG-CRP1 from 2022-04-14 to 2022-04-21
# Fetching data for WG-CRP1 from 2022-04-21 to 2022-04-28
# Fetching data for WG-CRP1 from 2022-04-28 to 2022-05-05
# Fetching data for WG-CRP1 from 2022-05-05 to 2022-05-12
# Fetching data for WG-CRP1 from 2022-05-12 to 2022-05-19
# Fetching data for WG-CRP1 from 2022-05-19 to 2022-05-26
# Fetching data for WG-CRP1 from 2022-05-26 to 2022-06-02
# Fetching data for WG-CRP1 from 2022-06-02 to 2022-06-09
# Fetching data for WG-CRP1 from 2022-06-09 to 2022-06-16
# Fetching data for WG-CRP1 from 2022-06-16 to 2022-06-23
# Fetching data for WG-CRP1 from 2022-06-23 to 2022-06-30
# Fetching data for WG-CRP1 from 2022-06-30 to 2022-07-07
# Fetching data for WG-CRP1 from 2022-07-07 to 2022-07-14
# Fetching data for WG-CRP1 from 2022-07-14 to 2022-07-21
# Fetching data for WG-CRP1 from 2022-07-21 to 2022-07-28
# Fetching data for WG-CRP1 from 2022-07-28 to 2022-08-04
# Fetching data for WG-CRP1 from 2022-08-04 to 2022-08-11
# Fetching data for WG-CRP1 from 2022-08-11 to 2022-08-18
# Fetching data for WG-CRP1 from 2022-08-18 to 2022-08-25
# Fetching data for WG-CRP1 from 2022-08-25 to 2022-09-01
# Fetching data for WG-CRP1 from 2022-09-01 to 2022-09-08
# Fetching data for WG-CRP1 from 2022-09-08 to 2022-09-15
# Fetching data for WG-CRP1 from 2022-09-15 to 2022-09-22
# Fetching data for WG-CRP1 from 2022-09-22 to 2022-09-29
# Fetching data for WG-CRP1 from 2022-09-29 to 2022-10-06
# Fetching data for WG-CRP1 from 2022-10-06 to 2022-10-13
# Fetching data for WG-CRP1 from 2022-10-13 to 2022-10-20
# Fetching data for WG-CRP1 from 2022-10-20 to 2022-10-27
# Fetching data for WG-CRP1 from 2022-10-27 to 2022-11-03
# Fetching data for WG-CRP1 from 2022-11-03 to 2022-11-10
# Fetching data for WG-CRP1 from 2022-11-10 to 2022-11-17
# Fetching data for WG-CRP1 from 2022-11-17 to 2022-11-24
# Fetching data for WG-CRP1 from 2022-11-24 to 2022-12-01
# Fetching data for WG-CRP1 from 2022-12-01 to 2022-12-08
# Fetching data for WG-CRP1 from 2022-12-08 to 2022-12-15
# Fetching data for WG-CRP1 from 2022-12-15 to 2022-12-22
# Fetching data for WG-CRP1 from 2022-12-22 to 2022-12-29
# Fetching data for WG-CRP1 from 2022-12-29 to 2023-01-05
# Fetching data for WG-CRP1 from 2023-01-05 to 2023-01-12
# Fetching data for WG-CRP1 from 2023-01-12 to 2023-01-19
# Fetching data for WG-CRP1 from 2023-01-19 to 2023-01-26
# Fetching data for WG-CRP1 from 2023-01-26 to 2023-02-02
# Fetching data for WG-CRP1 from 2023-02-02 to 2023-02-09
# Fetching data for WG-CRP1 from 2023-02-09 to 2023-02-16
# Fetching data for WG-CRP1 from 2023-02-16 to 2023-02-23
# Fetching data for WG-CRP1 from 2023-02-23 to 2023-03-02
# Fetching data for WG-CRP1 from 2023-03-02 to 2023-03-09
# Fetching data for WG-CRP1 from 2023-03-09 to 2023-03-16
# Fetching data for WG-CRP1 from 2023-03-16 to 2023-03-23
# Fetching data for WG-CRP1 from 2023-03-23 to 2023-03-30
# Fetching data for WG-CRP1 from 2023-03-30 to 2023-04-06
# Fetching data for WG-CRP1 from 2023-04-06 to 2023-04-13
# Fetching data for WG-CRP1 from 2023-04-13 to 2023-04-20
# Fetching data for WG-CRP1 from 2023-04-20 to 2023-04-27
# Fetching data for WG-CRP1 from 2023-04-27 to 2023-05-04
# Fetching data for WG-CRP1 from 2023-05-04 to 2023-05-11
# Fetching data for WG-CRP1 from 2023-05-11 to 2023-05-18
# Fetching data for WG-CRP1 from 2023-05-18 to 2023-05-25
# Fetching data for WG-CRP1 from 2023-05-25 to 2023-06-01
# Fetching data for WG-CRP1 from 2023-06-01 to 2023-06-08
# Fetching data for WG-CRP1 from 2023-06-08 to 2023-06-15
# Fetching data for WG-CRP1 from 2023-06-15 to 2023-06-22
# Fetching data for WG-CRP1 from 2023-06-22 to 2023-06-29
# Fetching data for WG-CRP1 from 2023-06-29 to 2023-07-06
# Fetching data for WG-CRP1 from 2023-07-06 to 2023-07-13
# Fetching data for WG-CRP1 from 2023-07-13 to 2023-07-20
# Fetching data for WG-CRP1 from 2023-07-20 to 2023-07-27
# Fetching data for WG-CRP1 from 2023-07-27 to 2023-08-03
# Fetching data for WG-CRP1 from 2023-08-03 to 2023-08-10
# Fetching data for WG-CRP1 from 2023-08-10 to 2023-08-17
# Fetching data for WG-CRP1 from 2023-08-17 to 2023-08-24
# Fetching data for WG-CRP1 from 2023-08-24 to 2023-08-31
# Fetching data for WG-CRP1 from 2023-08-31 to 2023-09-07
# Fetching data for WG-CRP1 from 2023-09-07 to 2023-09-14
# Fetching data for WG-CRP1 from 2023-09-14 to 2023-09-21
# Fetching data for WG-CRP1 from 2023-09-21 to 2023-09-28
# Fetching data for WG-CRP1 from 2023-09-28 to 2023-10-05
# Fetching data for WG-CRP1 from 2023-10-05 to 2023-10-12
# Fetching data for WG-CRP1 from 2023-10-12 to 2023-10-19
# Fetching data for WG-CRP1 from 2023-10-19 to 2023-10-26
# Fetching data for WG-CRP1 from 2023-10-26 to 2023-11-02
# Fetching data for WG-CRP1 from 2023-11-02 to 2023-11-09
# Fetching data for WG-CRP1 from 2023-11-09 to 2023-11-16
# Fetching data for WG-CRP1 from 2023-11-16 to 2023-11-23
# Fetching data for WG-CRP1 from 2023-11-23 to 2023-11-30
# Fetching data for WG-CRP1 from 2023-11-30 to 2023-12-07
# Fetching data for WG-CRP1 from 2023-12-07 to 2023-12-14
# Fetching data for WG-CRP1 from 2023-12-14 to 2023-12-21
# Fetching data for WG-CRP1 from 2023-12-21 to 2023-12-28
# Fetching data for WG-CRP1 from 2023-12-28 to 2024-01-04
# Fetching data for WG-CRP1 from 2024-01-04 to 2024-01-11
# Fetching data for WG-CRP1 from 2024-01-11 to 2024-01-18
# Fetching data for WG-CRP1 from 2024-01-18 to 2024-01-25
# Fetching data for WG-CRP1 from 2024-01-25 to 2024-02-01
# Fetching data for WG-CRP1 from 2024-02-01 to 2024-02-08
# Fetching data for WG-CRP1 from 2024-02-08 to 2024-02-15
# Fetching data for WG-CRP1 from 2024-02-15 to 2024-02-22
# Fetching data for WG-CRP1 from 2024-02-22 to 2024-02-29
# Fetching data for WG-CRP1 from 2024-02-29 to 2024-03-07
# Fetching data for WG-CRP1 from 2024-03-07 to 2024-03-14
# Fetching data for WG-CRP1 from 2024-03-14 to 2024-03-21
# Fetching data for WG-CRP1 from 2024-03-21 to 2024-03-28
# Fetching data for WG-CRP1 from 2024-03-28 to 2024-04-04
# Fetching data for WG-CRP1 from 2024-04-04 to 2024-04-11
# Fetching data for WG-CRP1 from 2024-04-11 to 2024-04-18
# Fetching data for WG-CRP1 from 2024-04-18 to 2024-04-25
# Fetching data for WG-CRP1 from 2024-04-25 to 2024-05-02
# Fetching data for WG-CRP1 from 2024-05-02 to 2024-05-05
# Fetching data for WG-VMS1 from 2022-06-08 to 2022-06-15
# Fetching data for WG-VMS1 from 2022-06-15 to 2022-06-22
# Fetching data for WG-VMS1 from 2022-06-22 to 2022-06-29
# Fetching data for WG-VMS1 from 2022-06-29 to 2022-07-06
# Fetching data for WG-VMS1 from 2022-07-06 to 2022-07-13
# Fetching data for WG-VMS1 from 2022-07-13 to 2022-07-20
# Fetching data for WG-VMS1 from 2022-07-20 to 2022-07-27
# Fetching data for WG-VMS1 from 2022-07-27 to 2022-08-03
# Fetching data for WG-VMS1 from 2022-08-03 to 2022-08-10
# Fetching data for WG-VMS1 from 2022-08-10 to 2022-08-17
# Fetching data for WG-VMS1 from 2022-08-17 to 2022-08-24
# Fetching data for WG-VMS1 from 2022-08-24 to 2022-08-31
# Fetching data for WG-VMS1 from 2022-08-31 to 2022-09-07
# Fetching data for WG-VMS1 from 2022-09-07 to 2022-09-14
# Fetching data for WG-VMS1 from 2022-09-14 to 2022-09-21
# Fetching data for WG-VMS1 from 2022-09-21 to 2022-09-28
# Fetching data for WG-VMS1 from 2022-09-28 to 2022-10-05
# Fetching data for WG-VMS1 from 2022-10-05 to 2022-10-12
# Fetching data for WG-VMS1 from 2022-10-12 to 2022-10-19
# Fetching data for WG-VMS1 from 2022-10-19 to 2022-10-26
# Fetching data for WG-VMS1 from 2022-10-26 to 2022-11-02
# Fetching data for WG-VMS1 from 2022-11-02 to 2022-11-09
# Fetching data for WG-VMS1 from 2022-11-09 to 2022-11-16
# Fetching data for WG-VMS1 from 2022-11-16 to 2022-11-23
# Fetching data for WG-VMS1 from 2022-11-23 to 2022-11-30
# Fetching data for WG-VMS1 from 2022-11-30 to 2022-12-07
# Fetching data for WG-VMS1 from 2022-12-07 to 2022-12-14
# Fetching data for WG-VMS1 from 2022-12-14 to 2022-12-21
# Fetching data for WG-VMS1 from 2022-12-21 to 2022-12-28
# Fetching data for WG-VMS1 from 2022-12-28 to 2023-01-04
# Fetching data for WG-VMS1 from 2023-01-04 to 2023-01-11
# Fetching data for WG-VMS1 from 2023-01-11 to 2023-01-18
# Fetching data for WG-VMS1 from 2023-01-18 to 2023-01-25
# Fetching data for WG-VMS1 from 2023-01-25 to 2023-02-01
# Fetching data for WG-VMS1 from 2023-02-01 to 2023-02-08
# Fetching data for WG-VMS1 from 2023-02-08 to 2023-02-15
# Fetching data for WG-VMS1 from 2023-02-15 to 2023-02-22
# Fetching data for WG-VMS1 from 2023-02-22 to 2023-03-01
# Fetching data for WG-VMS1 from 2023-03-01 to 2023-03-08
# Fetching data for WG-VMS1 from 2023-03-08 to 2023-03-15
# Fetching data for WG-VMS1 from 2023-03-15 to 2023-03-22
# Fetching data for WG-VMS1 from 2023-03-22 to 2023-03-29
# Fetching data for WG-VMS1 from 2023-03-29 to 2023-04-05
# Fetching data for WG-VMS1 from 2023-04-05 to 2023-04-12
# Fetching data for WG-VMS1 from 2023-04-12 to 2023-04-19
# Fetching data for WG-VMS1 from 2023-04-19 to 2023-04-26
# Fetching data for WG-VMS1 from 2023-04-26 to 2023-05-03
# Fetching data for WG-VMS1 from 2023-05-03 to 2023-05-10
# Fetching data for WG-VMS1 from 2023-05-10 to 2023-05-17
# Fetching data for WG-VMS1 from 2023-05-17 to 2023-05-24
# Fetching data for WG-VMS1 from 2023-05-24 to 2023-05-31
# Fetching data for WG-VMS1 from 2023-05-31 to 2023-06-07
# Fetching data for WG-VMS1 from 2023-06-07 to 2023-06-14
# Fetching data for WG-VMS1 from 2023-06-14 to 2023-06-21
# Fetching data for WG-VMS1 from 2023-06-21 to 2023-06-28
# Fetching data for WG-VMS1 from 2023-06-28 to 2023-07-05
# Fetching data for WG-VMS1 from 2023-07-05 to 2023-07-12
# Fetching data for WG-VMS1 from 2023-07-12 to 2023-07-19
# Fetching data for WG-VMS1 from 2023-07-19 to 2023-07-26
# Fetching data for WG-VMS1 from 2023-07-26 to 2023-08-02
# Fetching data for WG-VMS1 from 2023-08-02 to 2023-08-09
# Fetching data for WG-VMS1 from 2023-08-09 to 2023-08-16
# Fetching data for WG-VMS1 from 2023-08-16 to 2023-08-23
# Fetching data for WG-VMS1 from 2023-08-23 to 2023-08-30
# Fetching data for WG-VMS1 from 2023-08-30 to 2023-09-06
# Fetching data for WG-VMS1 from 2023-09-06 to 2023-09-13
# Fetching data for WG-VMS1 from 2023-09-13 to 2023-09-20
# Fetching data for WG-VMS1 from 2023-09-20 to 2023-09-27
# Fetching data for WG-VMS1 from 2023-09-27 to 2023-10-04
# Fetching data for WG-VMS1 from 2023-10-04 to 2023-10-11
# Fetching data for WG-VMS1 from 2023-10-11 to 2023-10-18
# Fetching data for WG-VMS1 from 2023-10-18 to 2023-10-25
# Fetching data for WG-VMS1 from 2023-10-25 to 2023-11-01
# Fetching data for WG-VMS1 from 2023-11-01 to 2023-11-08
# Fetching data for WG-VMS1 from 2023-11-08 to 2023-11-15
# Fetching data for WG-VMS1 from 2023-11-15 to 2023-11-22
# Fetching data for WG-VMS1 from 2023-11-22 to 2023-11-29
# Fetching data for WG-VMS1 from 2023-11-29 to 2023-12-06
# Fetching data for WG-VMS1 from 2023-12-06 to 2023-12-13
# Fetching data for WG-VMS1 from 2023-12-13 to 2023-12-20
# Fetching data for WG-VMS1 from 2023-12-20 to 2023-12-27
# Fetching data for WG-VMS1 from 2023-12-27 to 2024-01-03
# Fetching data for WG-VMS1 from 2024-01-03 to 2024-01-10
# Fetching data for WG-VMS1 from 2024-01-10 to 2024-01-17
# Fetching data for WG-VMS1 from 2024-01-17 to 2024-01-24
# Fetching data for WG-VMS1 from 2024-01-24 to 2024-01-31
# Fetching data for WG-VMS1 from 2024-01-31 to 2024-02-07
# Fetching data for WG-VMS1 from 2024-02-07 to 2024-02-14
# Fetching data for WG-VMS1 from 2024-02-14 to 2024-02-21
# Fetching data for WG-VMS1 from 2024-02-21 to 2024-02-28
# Fetching data for WG-VMS1 from 2024-02-28 to 2024-03-06
# Fetching data for WG-VMS1 from 2024-03-06 to 2024-03-13
# Fetching data for WG-VMS1 from 2024-03-13 to 2024-03-20
# Fetching data for WG-VMS1 from 2024-03-20 to 2024-03-27
# Fetching data for WG-VMS1 from 2024-03-27 to 2024-04-03
# Fetching data for WG-VMS1 from 2024-04-03 to 2024-04-10
# Fetching data for WG-VMS1 from 2024-04-10 to 2024-04-17
# Fetching data for WG-VMS1 from 2024-04-17 to 2024-04-24
# Fetching data for WG-VMS1 from 2024-04-24 to 2024-05-01
# Fetching data for WG-VMS1 from 2024-05-01 to 2024-05-08
# Fetching data for WG-VMS1 from 2024-05-08 to 2024-05-15
# All data has been processed and saved.
